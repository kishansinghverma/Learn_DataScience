# %%
import pandas as pd
import numpy as np

# %%
pd.read_excel("Datasets/covidAnalysis.xls", sheet_name=0)
# Out:
#                           state  confirmed  recovered  deaths  \
# 0                   Maharashtra      43601      39314    3060
# 1                         Delhi      17125      10999     812
# 2                    Tamil Nadu      14399      16999     269
# 3                       Gujarat       5186      13635    1249
# 4                   West Bengal       4488       3303     396
# 5                 Uttar Pradesh       4076       6185     275
# 6                     Karnataka       3259       2132      61
# 7             Jammu and Kashmir       2830       1216      41
# 8                     Rajasthan       2718       7641     240
# 9                Madhya Pradesh       2658       6331     412
# 10                        Bihar       2578       2480      30
# 11                      Haryana       2286       2134      28
# 12               Andhra Pradesh       1951       2682      75
# 13                        Assam       1946        615       4
# ...

# %%
df=pd.DataFrame({ 'Roll No':[1,2,3], 'Name':['Kishan', 'Amit', 'Rajat']})
df
# Out:
#    Roll No    Name
# 0        1  Kishan
# 1        2    Amit
# 2        3   Rajat

# %%
df['Marks']=[20, 23, 21]
df
# Out:
#    Roll No    Name  Marks
# 0        1  Kishan     20
# 1        2    Amit     23
# 2        3   Rajat     21

# %%
df.insert(3, 'Course', ['CSE', 'ECE','MCE']) #insert a column, already inplace
df
# Out:
#    Roll No    Name  Marks Course
# 0        1  Kishan     20    CSE
# 1        2    Amit     23    ECE
# 2        3   Rajat     21    MCE

# %%
df.drop('Marks', axis=1, inplace=True) #drop a column

# %%
df
# Out:
#    Roll No    Name Course
# 0        1  Kishan    CSE
# 1        2    Amit    ECE
# 2        3   Rajat    MCE

# %%
#Accessing Individual Element & Updating
df.at[1, 'Name']
# Out:
# 'Amit'

# %%
df.iat[2, 1]
# Out:
# 'Rajat'

# %%
df.loc[1, 'Name']
# Out:
# 'Amit'

# %%
df.loc[:, 'Course']
# Out:
# 0    CSE
# 1    ECE
# 2    MCE
# Name: Course, dtype: object

# %%
df.loc[2]
# Out:
# Roll No        3
# Name       Rajat
# Course       MCE
# Name: 2, dtype: object

# %%
df.iloc[:, 1]
# Out:
# 0    Kishan
# 1      Amit
# 2     Rajat
# Name: Name, dtype: object

# %%
df.iloc[1]
# Out:
# Roll No       2
# Name       Amit
# Course      ECE
# Name: 1, dtype: object

# %%
df
# Out:
#    Roll No    Name Course
# 0        1  Kishan    CSE
# 1        2    Amit    ECE
# 2        3   Rajat    MCE

# %%
df.iloc[1,1]='Sachin'
df
# Out:
#    Roll No    Name Course
# 0        1  Kishan    CSE
# 1        2  Sachin    ECE
# 2        3   Rajat    MCE

# %%
df['Name'] #Single Column
# Out:
# 0    Kishan
# 1    Sachin
# 2     Rajat
# Name: Name, dtype: object

# %%
df[['Name','Course']] #Multiple column
# Out:
#      Name Course
# 0  Kishan    CSE
# 1  Sachin    ECE
# 2   Rajat    MCE

# %%
df
# Out:
#    Roll No    Name Course
# 0        1  Kishan    CSE
# 1        2  Sachin    ECE
# 2        3   Rajat    MCE

# %%
df['Mark']=[10, 12, 23]
df
# Out:
#    Roll No    Name Course  Mark
# 0        1  Kishan    CSE    10
# 1        2  Sachin    ECE    12
# 2        3   Rajat    MCE    23

# %%
df.loc[3]=[4, 'Amit', 'Mech', 24]
df
# Out:
#    Roll No    Name Course  Mark
# 0        1  Kishan    CSE    10
# 1        2  Sachin    ECE    12
# 2        3   Rajat    MCE    23
# 3        4    Amit   Mech    24

# %%
df.loc[1:3, 'Name':'Mark'] #Selective Range
# Out:
#      Name Course  Mark
# 1  Sachin    ECE    12
# 2   Rajat    MCE    23
# 3    Amit   Mech    24

# %%
df.iloc[0:4, 1:3]
# Out:
#      Name Course
# 0  Kishan    CSE
# 1  Sachin    ECE
# 2   Rajat    MCE
# 3    Amit   Mech

# %%
df
# Out:
#    Roll No    Name Course  Mark
# 0        1  Kishan    CSE    10
# 1        2  Sachin    ECE    12
# 2        3   Rajat    MCE    23
# 3        4    Amit   Mech    24

# %%
df[df['Mark']>12] #Conditional Selection
# Out:
#    Roll No   Name Course  Mark
# 2        3  Rajat    MCE    23
# 3        4   Amit   Mech    24

# %%
df[(df['Course']=='MCE') & (df['Mark']>12)] #Multiple Condition Selection
# Out:
#    Roll No   Name Course  Mark
# 2        3  Rajat    MCE    23

# %%
df.sort_values(by='Name') #Sorting Values
# Out:
#    Roll No    Name Course  Mark
# 3        4    Amit   Mech    24
# 0        1  Kishan    CSE    10
# 2        3   Rajat    MCE    23
# 1        2  Sachin    ECE    12

# %%
df.sort_index() #Sort by index
# Out:
#    Roll No    Name Course  Mark
# 0        1  Kishan    CSE    10
# 1        2  Sachin    ECE    12
# 2        3   Rajat    MCE    23
# 3        4    Amit   Mech    24

# %%
df.sort_values(by='Course', ascending=False)
# Out:
#    Roll No    Name Course  Mark
# 3        4    Amit   Mech    24
# 2        3   Rajat    MCE    23
# 1        2  Sachin    ECE    12
# 0        1  Kishan    CSE    10

# %%
df.columns
# Out:
# Index(['Roll No', 'Name', 'Course', 'Mark'], dtype='object')

# %%
#Another way of exploring dataframe
for x in df:
    for y in df[x]:
        print(y, end=" ")
    print()
# Out:
# 1 2 3 4
# Kishan Sachin Rajat Amit
# CSE ECE MCE Mech
# 10 12 23 24

# %%
df.index
# Out:
# Int64Index([0, 1, 2, 3], dtype='int64')

# %%
df.index=['A', 'B', 'C', 'D']

# %%
df
# Out:
#    Roll No    Name Course  Mark
# A        1  Kishan    CSE    10
# B        2  Sachin    ECE    12
# C        3   Rajat    MCE    23
# D        4    Amit   Mech    24

# %%
df.columns=['Rolls', 'Names', 'Courses', 'Marks']

# %%
df
# Out:
#    Rolls   Names Courses  Marks
# A      1  Kishan     CSE     10
# B      2  Sachin     ECE     12
# C      3   Rajat     MCE     23
# D      4    Amit    Mech     24

# %%
df.columns
# Out:
# Index(['Rolls', 'Names', 'Courses', 'Marks'], dtype='object')

# %%
df1=pd.DataFrame({'Rolls':[5, 6], 'Names':['Deva', 'Ravi'], 'Courses':['Mech', 'CSE'], 'Marks':[13, 23]})
df1
# Out:
#    Rolls Names Courses  Marks
# 0      5  Deva    Mech     13
# 1      6  Ravi     CSE     23

# %%
df2=pd.DataFrame({'Rolls':[8, 10], 'Names':['Jerry', 'Tom'], 'Courses':['UKG', 'LKG'], 'Marks':[15, 18]})
df2
# Out:
#    Rolls  Names Courses  Marks
# 0      8  Jerry     UKG     15
# 1     10    Tom     LKG     18

# %%
df.append(df2) #Indexing as it is
# Out:
#    Rolls   Names Courses  Marks
# A      1  Kishan     CSE     10
# B      2  Sachin     ECE     12
# C      3   Rajat     MCE     23
# D      4    Amit    Mech     24
# 0      8   Jerry     UKG     15
# 1     10     Tom     LKG     18

# %%
df.append(df2, ignore_index=True) #Rebuild Index
# Out:
#    Rolls   Names Courses  Marks
# 0      1  Kishan     CSE     10
# 1      2  Sachin     ECE     12
# 2      3   Rajat     MCE     23
# 3      4    Amit    Mech     24
# 4      8   Jerry     UKG     15
# 5     10     Tom     LKG     18

# %%
df3=df.append(df1, ignore_index=True).append(df2, ignore_index=True)
df3
# Out:
#    Rolls   Names Courses  Marks
# 0      1  Kishan     CSE     10
# 1      2  Sachin     ECE     12
# 2      3   Rajat     MCE     23
# 3      4    Amit    Mech     24
# 4      5    Deva    Mech     13
# 5      6    Ravi     CSE     23
# 6      8   Jerry     UKG     15
# 7     10     Tom     LKG     18

# %%
df3.to_excel("Datasets/exportTest.xls")

# %%
data=pd.read_excel("Datasets/exportTest.xls", skiprows=[3, 4], nrows=5)
data
# Out:
#    Unnamed: 0  Rolls   Names Courses  Marks
# 0           0      1  Kishan     CSE     10
# 1           1      2  Sachin     ECE     12
# 2           4      5    Deva    Mech     13

# %%
data=pd.read_csv("Datasets/heights.csv")
data
# Out:
#     order                    name  height(cm)
# 0       1       George Washington         189
# 1       2              John Adams         170
# 2       3        Thomas Jefferson         189
# 3       4           James Madison         163
# 4       5            James Monroe         183
# 5       6       John Quincy Adams         171
# 6       7          Andrew Jackson         185
# 7       8        Martin Van Buren         168
# 8       9  William Henry Harrison         173
# 9      10              John Tyler         183
# 10     11           James K. Polk         173
# 11     12          Zachary Taylor         173
# 12     13        Millard Fillmore         175
# 13     14         Franklin Pierce         178
# 14     15          James Buchanan         183
# 15     16         Abraham Lincoln         193
# 16     17          Andrew Johnson         178
# 17     18        Ulysses S. Grant         173
# 18     19     Rutherford B. Hayes         174
# ...

# %%
data.sort_values(by='height(cm)')
# Out:
#     order                    name  height(cm)
# 3       4           James Madison         163
# 7       8        Martin Van Buren         168
# 21     23       Benjamin Harrison         168
# 1       2              John Adams         170
# 22     25        William McKinley         170
# 5       6       John Quincy Adams         171
# 8       9  William Henry Harrison         173
# 10     11           James K. Polk         173
# 11     12          Zachary Taylor         173
# 17     18        Ulysses S. Grant         173
# 18     19     Rutherford B. Hayes         174
# 12     13        Millard Fillmore         175
# 30     33         Harry S. Truman         175
# 36     39            Jimmy Carter         177
# 16     17          Andrew Johnson         178
# 13     14         Franklin Pierce         178
# 23     26      Theodore Roosevelt         178
# 27     30         Calvin Coolidge         178
# 31     34    Dwight D. Eisenhower         179
# ...

# %%
data=pd.read_html("https://www.mohfw.gov.in")
data[0]
# Out:
# Empty DataFrame
# Columns: [(S. No., S. No.), (Name of State / UT, Name of State / UT), (Active Cases*, Total), (Active Cases*, Change since yesterdayChange since yesterday), (Cured/Discharged/Migrated*, Cumulative), (Cured/Discharged/Migrated*, Change since yesterday), (Deaths**, Cumulative), (Deaths**, Change since yesterday)]
# Index: []

# %%
ew=pd.ExcelWriter('Datasets/testGenerate.xlsx',engine='openpyxl')
df.to_excel(ew,sheet_name='abc')
ew.close()

# %%
#Start -> Series Object
data=pd.Series(range(2, 11, 2))
data
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64

# %%
#One Dimensional Array as series
data['x']=range(3, 16, 3)
data
# Out:
# 0                    2
# 1                    4
# 2                    6
# 3                    8
# 4                   10
# x    (3, 6, 9, 12, 15)
# dtype: object

# %%
s1=pd.Series(['A', 'B', 'C', 'D'])
s2=pd.Series([1,2,3,4])
s1, s2
# Out:
# (0    A
#  1    B
#  2    C
#  3    D
#  dtype: object,
#  0    1
#  1    2
#  2    3
#  3    4
#  dtype: int64)

# %%
#Creating DataFrame by different ways
pd.DataFrame([s1, s2])
# Out:
#    0  1  2  3
# 0  A  B  C  D
# 1  1  2  3  4

# %%
pd.DataFrame({'Str':s1, 'Int':s2})
# Out:
#   Str  Int
# 0   A    1
# 1   B    2
# 2   C    3
# 3   D    4

# %%
pd.DataFrame([[1,2],[4,5], [7,8]], columns=['A', 'B'])
# Out:
#    A  B
# 0  1  2
# 1  4  5
# 2  7  8

# %%
age={'Rajat':25, 'Sachin':22, 'Kishan':21}
marks={'Rajat':90, 'Sachin':87, 'Kishan':98}
pd.DataFrame({'Age':age, 'Marks':marks})
# Out:
#         Age  Marks
# Rajat    25     90
# Sachin   22     87
# Kishan   21     98

# %%
x=np.random.randint(1, 30, size=(3,4))
x
# Out:
# array([[19, 22, 20, 28],
#        [11, 17,  7,  4],
#        [14,  1, 18, 18]])

# %%
df=pd.DataFrame(x, columns=['a', 'b', 'c', 'd'], index=['x', 'y','z'])
df
# Out:
#     a   b   c   d
# x  19  22  20  28
# y  11  17   7   4
# z  14   1  18  18

# %%
df.index
# Out:
# Index(['x', 'y', 'z'], dtype='object')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.index=range(1, 151)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 1             5.1          3.5           1.4          0.2     setosa
# 2             4.9          3.0           1.4          0.2     setosa
# 3             4.7          3.2           1.3          0.2     setosa
# 4             4.6          3.1           1.5          0.2     setosa
# 5             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 146           6.7          3.0           5.2          2.3  virginica
# 147           6.3          2.5           5.0          1.9  virginica
# 148           6.5          3.0           5.2          2.0  virginica
# 149           6.2          3.4           5.4          2.3  virginica
# 150           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.loc[1] #Always access with explicit indexing
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 1, dtype: object

# %%
df.iloc[1] #Always access with implicit indexing
# Out:
# sepal_length       4.9
# sepal_width          3
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 2, dtype: object

# %%
df.iloc[1,1]
# Out:
# 3.0

# %%
df.loc[1,'sepal_length']
# Out:
# 5.1

# %%
df.values #Gives array with extracted values from dataframe
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 'setosa'],
#        [4.9, 3.0, 1.4, 0.2, 'setosa'],
#        [4.7, 3.2, 1.3, 0.2, 'setosa'],
#        [4.6, 3.1, 1.5, 0.2, 'setosa'],
#        [5.0, 3.6, 1.4, 0.2, 'setosa'],
#        [5.4, 3.9, 1.7, 0.4, 'setosa'],
#        [4.6, 3.4, 1.4, 0.3, 'setosa'],
#        [5.0, 3.4, 1.5, 0.2, 'setosa'],
#        [4.4, 2.9, 1.4, 0.2, 'setosa'],
#        [4.9, 3.1, 1.5, 0.1, 'setosa'],
#        [5.4, 3.7, 1.5, 0.2, 'setosa'],
#        [4.8, 3.4, 1.6, 0.2, 'setosa'],
#        [4.8, 3.0, 1.4, 0.1, 'setosa'],
#        [4.3, 3.0, 1.1, 0.1, 'setosa'],
#        [5.8, 4.0, 1.2, 0.2, 'setosa'],
#        [5.7, 4.4, 1.5, 0.4, 'setosa'],
#        [5.4, 3.9, 1.3, 0.4, 'setosa'],
#        [5.1, 3.5, 1.4, 0.3, 'setosa'],
#        [5.7, 3.8, 1.7, 0.3, 'setosa'],
#        [5.1, 3.8, 1.5, 0.3, 'setosa'],
#        [5.4, 3.4, 1.7, 0.2, 'setosa'],
#        [5.1, 3.7, 1.5, 0.4, 'setosa'],
#        [4.6, 3.6, 1.0, 0.2, 'setosa'],
#        [5.1, 3.3, 1.7, 0.5, 'setosa'],
# ...

# %%
df.values[0] #Always works by implicit indexing as we are working on array type
# Out:
# array([5.1, 3.5, 1.4, 0.2, 'setosa'], dtype=object)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 1             5.1          3.5           1.4          0.2     setosa
# 2             4.9          3.0           1.4          0.2     setosa
# 3             4.7          3.2           1.3          0.2     setosa
# 4             4.6          3.1           1.5          0.2     setosa
# 5             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 146           6.7          3.0           5.2          2.3  virginica
# 147           6.3          2.5           5.0          1.9  virginica
# 148           6.5          3.0           5.2          2.0  virginica
# 149           6.2          3.4           5.4          2.3  virginica
# 150           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.loc[7:5:-1,'sepal_width':'petal_width'] #Two dimensional data accessing
# Out:
#    sepal_width  petal_length  petal_width
# 7          3.4           1.4          0.3
# 6          3.9           1.7          0.4
# 5          3.6           1.4          0.2

# %%
df.iloc[2:4, 0:2]
# Out:
#    sepal_length  sepal_width
# 3           4.7          3.2
# 4           4.6          3.1

# %%
# %timeit df.loc[df['sepal_length']>5, ['petal_length']] #Masking with selection
# Out:
# 1.66 ms ± 58.3 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit df[df.sepal_length>5]['petal_length'] #One more
# Out:
# 837 µs ± 105 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
