# %%
import pandas as pd

# %%
pd.read_excel("Datasets/covidAnalysis.xls", sheet_name=0)
# Out:
#                           state  confirmed  recovered  deaths  rate_death  \
# 0                   Maharashtra      52667      15786    1695    3.218334
# 1                    Tamil Nadu      17082       8731     118    0.690786
# 2                       Gujarat      14460       6636     888    6.141079
# 3                         Delhi      14053       6771     276    1.963993
# 4                     Rajasthan       7300       3951     167    2.287671
# 5                Madhya Pradesh       6859       3571     300    4.373815
# 6                 Uttar Pradesh       6532       3581     165    2.526026
# 7                   West Bengal       3816       1414     278    7.285115
# 8                Andhra Pradesh       3110       1896      56    1.800643
# 9                         Bihar       2730        749      13    0.476190
# 10                    Karnataka       2182        705      44    2.016499
# 11                       Punjab       2060       1898      40    1.941748
# ...

# %%
df=pd.DataFrame({ 'Roll No':[1,2,3], 'Name':['Kishan', 'Amit', 'Rajat']})
df
# Out:
#    Roll No    Name
# 0        1  Kishan
# 1        2    Amit
# 2        3   Rajat

# %%
df['Marks']=[20, 23, 21]
df
# Out:
#    Roll No    Name  Marks
# 0        1  Kishan     20
# 1        2    Amit     23
# 2        3   Rajat     21

# %%
df.insert(3, 'Course', ['CSE', 'ECE','MCE'])
df
# Out:
#    Roll No    Name  Marks Course
# 0        1  Kishan     20    CSE
# 1        2    Amit     23    ECE
# 2        3   Rajat     21    MCE

# %%
df.delete('Marks')
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-1f2bf6d28733> in <module>
# ----> 1 df.delete('Marks')
#       2 df
#
# AttributeError: type object 'DataFrame' has no attribute 'delete'
