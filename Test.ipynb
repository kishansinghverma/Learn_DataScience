# %%
import numpy as np
import pandas as pd
normalsort=[]
mergesort=[]
quicksort=[]
heapsort=[]
stablesort=[]

sizes=[100]

for s in sizes:
    for _ in range(20):
        arr=np.random.randint(10000000, size=s)
    
        x=np.copy(arr)
        r2=%timeit -n1 -r1 -o np.sort(x, kind='quicksort')
        quicksort.append(r2.average)
    
        x=np.copy(arr)
        r3=%timeit -n1 -r1 -o np.sort(x, kind='mergesort')
        mergesort.append(r3.average)

        x=np.copy(arr)
        r4=%timeit -n1 -r1 -o np.sort(x, kind='heapsort')
        heapsort.append(r4.average)
    
        x=np.copy(arr)
        r5=%timeit -n1 -r1 -o np.sort(x, kind='stablesort')
        stablesort.append(r5.average)
# Out:
# 34 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 38.2 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 24.3 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 261 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 17.6 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 18.5 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 18.6 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 18 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 29.4 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 19.3 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 211 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 18 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 39.1 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 19.5 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 16.9 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 17.7 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 17.6 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 18 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 18.6 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 17.4 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 30.3 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 18.7 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 18.8 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 18.8 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 16.4 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 39.9 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 19.4 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 17.6 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 18.1 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 17.7 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 18.4 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 23.2 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 38.7 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 20.3 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 18.3 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 22.6 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 17.2 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 18.6 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 20 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 17.3 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 17.6 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 30.2 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 18.5 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 17.2 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 20.2 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 16.1 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 31 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 17.9 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 20.2 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 18.4 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 21.2 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 18.4 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 17 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 16.6 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 17.8 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 39.8 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 19.3 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 17.3 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 19.7 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 17.8 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 16 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 18.3 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 24.8 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 29.4 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 17 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 16.7 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 19.6 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 16.4 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 17.5 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 17.3 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 20.7 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 16.5 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 16.9 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 43.6 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 23.4 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 17.1 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 16 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 16.3 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 21 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 17.4 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
import matplotlib.pyplot as plt
plt.plot(normalsort, color='black')
plt.plot(quicksort, color='red')
plt.plot(heapsort, color='green')
plt.plot(stablesort, color='blue')
plt.plot(mergesort, color='yellow')

# %%
x=np.array([[0.61185289, 0.13949386],
       [0.29214465, 0.36636184],
       [0.45606998, 0.78517596],
       [0.19967378, 0.51423444],
       [0.59241457, 0.04645041],
       [0.60754485, 0.17052412],
       [0.06505159, 0.94888554],
       [0.96563203, 0.80839735],
       [0.30461377, 0.09767211],
       [0.68423303, 0.44015249]])
x
# Out:
# array([[0.61185289, 0.13949386],
#        [0.29214465, 0.36636184],
#        [0.45606998, 0.78517596],
#        [0.19967378, 0.51423444],
#        [0.59241457, 0.04645041],
#        [0.60754485, 0.17052412],
#        [0.06505159, 0.94888554],
#        [0.96563203, 0.80839735],
#        [0.30461377, 0.09767211],
#        [0.68423303, 0.44015249]])

# %%
plt.xticks(np.arange(0, 1.1, .1))
plt.yticks(np.arange(0, 1.1, .1))

for p in x:
    plt.scatter(p[0], p[1])
plt.legend(np.arange(10))

# %%
arr=np.random.randint(200, size=[10,4])
arr
# Out:
# array([[ 26,  71, 154,  96],
#        [ 55,  14, 121,  44],
#        [137, 155, 140, 118],
#        [ 51, 181,  89,  83],
#        [101, 177, 141, 172],
#        [165,  39,  77,  88],
#        [ 74, 154,  67,  21],
#        [  9,  19,  16,   3],
#        [ 96, 143, 108,  69],
#        [133,  27, 184,  98]])

# %%
plt.scatter(arr[:, 0], arr[:, 1], arr[:, 2], arr[:, 3])

# %%
X = np.random.rand(10, 2)

# %%
X
# Out:
# array([[0.24216263, 0.65917188],
#        [0.3508981 , 0.76392428],
#        [0.58526616, 0.33808131],
#        [0.0820484 , 0.49244856],
#        [0.10548642, 0.76893225],
#        [0.71776447, 0.90635499],
#        [0.32182595, 0.41368043],
#        [0.2243582 , 0.34697661],
#        [0.77667984, 0.31219701],
#        [0.31380657, 0.47614601]])

# %%
X[:, np.newaxis, :]
# Out:
# array([[[0.24216263, 0.65917188]],
#
#        [[0.3508981 , 0.76392428]],
#
#        [[0.58526616, 0.33808131]],
#
#        [[0.0820484 , 0.49244856]],
#
#        [[0.10548642, 0.76893225]],
#
#        [[0.71776447, 0.90635499]],
#
#        [[0.32182595, 0.41368043]],
#
#        [[0.2243582 , 0.34697661]],
#
#        [[0.77667984, 0.31219701]],
#
#        [[0.31380657, 0.47614601]]])

# %%
x=np.random.randint(20, size=[10, 2])
x
# Out:
# array([[ 2, 18],
#        [ 3,  0],
#        [ 4, 17],
#        [14,  7],
#        [10,  2],
#        [18,  0],
#        [ 2, 17],
#        [13,  6],
#        [12,  3],
#        [ 3,  9]])

# %%
Max=10000

factors=[2]*(Max+1)
factors[1]=1

for x in range(2, (Max//2)):
    for y in range(x,Max+1, x):
        if(y!=x and y%x==0):
            factors[y]+=1
nums=[]

for x in range(Max+1):
    sum=0
    for i in range(1, len(factors[1:])):
        sum+=factors[i]
        if(sum>=x):
            nums.append(i)
            break;             
plt.plot(range(1, len(nums)+1), nums)

# %%
nm=list(np.arange(0, 9, 0.01))
fn=list(map(np.sin, nm))
plt.plot(nm, fn)

# %%
plt.plot(np.random.randint(10, size= [5,10]))
# Out:
# [<matplotlib.lines.Line2D at 0x7f9e112f9390>,
#  <matplotlib.lines.Line2D at 0x7f9e112f9590>,
#  <matplotlib.lines.Line2D at 0x7f9e112f9750>,
#  <matplotlib.lines.Line2D at 0x7f9e112f9910>,
#  <matplotlib.lines.Line2D at 0x7f9e112f9ad0>,
#  <matplotlib.lines.Line2D at 0x7f9e112f9c90>,
#  <matplotlib.lines.Line2D at 0x7f9e112f9ed0>,
#  <matplotlib.lines.Line2D at 0x7f9e113010d0>,
#  <matplotlib.lines.Line2D at 0x7f9e112f9a90>,
#  <matplotlib.lines.Line2D at 0x7f9e112f9cd0>]
