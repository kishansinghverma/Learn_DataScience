# %%
from bs4 import BeautifulSoup

# %%
import urllib.request
url="https://www.mohfw.gov.in/"
req = urllib.request.Request(url)
resp = urllib.request.urlopen(req)
respData = resp.read()

# %%
s=BeautifulSoup(respData, parser='html5lib') #html5lib, html5, html, html.parser, xml, lxml.. any from thiese parser

# %%
print(s.get_text(strip=True, separator="\n"))
# Out:
# MoHFW | Home
# window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-162536712-2');
# ...

# %%
link=s.find("a") #getting links
link
# Out:
# <a href="index.html">Home</a>

# %%
link.get_text() #geeting text
# Out:
# 'Home'

# %%
link.get('href') #getting attribute value
# Out:
# 'index.html'

# %%
s.find_all("a") #getting all anchors
# Out:
# [<a href="index.html">Home</a>,
#  <a class="trigger-update" href="#latest-update">Latest Updates</a>,
#  <a class="trigger-advisories" href="#site-advisories">Resources</a>,
#  <a data-id="travel" href="#">Travel Advisories</a>,
#  <a data-id="bh" href="#">Behavioural Health</a>,
#  <a data-id="citizens" href="#">Citizens</a>,
#  <a data-id="hospitals" href="#">Hospitals</a>,
#  <a data-id="tm" href="#">Training Material</a>,
#  <a data-id="state" href="#">States / Departments / Ministries</a>,
#  <a data-id="employees" href="#">Employees</a>,
#  <a data-id="awareness" href="#">Awareness Material</a>,
#  <a data-id="Inspirational" href="#">Inspirational series on Healthcare Service Personnel</a>,
#  <a class="trigger-awareness" href="#site-awareness">Awareness</a>,
#  <a class="trigger-faq" href="#site-faq">FAQs</a>,
#  <a class="m-close" href="#"><span aria-hidden="true" class="fa fa-times"></span></a>,
#  <a class="india-logo" href="https://india.gov.in" target="_blank">
# ...
